# %% [markdown]
# # Vision Model Demo

# %% [markdown]
# This notebook illustrates how to run a Neurokernel-based model comprising partial models of the fruit fly's lamina and medulla. First, we generate an input and execute the model:

# %%
# %cd ~/neurokernel/examples/vision/data
# %run gen_vis_input.py
# %cd ..
# %run vision_demo.py
# Out:
# /home/lev/neurokernel/examples/vision/data
# /home/lev/neurokernel/examples/vision
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# Next, we display the membrane potentials of all of the neurons in the two LPUs comprised by the
# model:

# %%
import matplotlib.ticker as ticker
fmt = lambda x, pos: '%2.2f' % (float(x)/1e4)
with h5py.File('./data/vision_input.h5', 'r') as fi, \
    h5py.File('lamina_output_gpot.h5','r') as fl, \
    h5py.File('medulla_output_gpot.h5', 'r') as fm:
    data_i = fi['real'].value;
    data_l = fl['array'].value;
    data_m = fm['array'].value;
rcParams['figure.dpi']=120; rcParams['figure.figsize']=(12,9)
subplot(311); set_cmap('gray');
gca().xaxis.set_major_formatter(ticker.FuncFormatter(fmt))
imshow(data_i.T); axis('tight'); title('Input'); ylabel('Neuron #'); 
subplot(312); set_cmap('gray');
gca().xaxis.set_major_formatter(ticker.FuncFormatter(fmt))
imshow(data_l.T); axis('tight'); title('Output (Lamina)'); ylabel('Neuron #');
subplot(313); set_cmap('gray');
gca().xaxis.set_major_formatter(ticker.FuncFormatter(fmt))
imshow(data_m.T); axis('tight'); title('Output (Medulla)'); ylabel('Neuron #');
xlabel('time (s)')
subplots_adjust();
